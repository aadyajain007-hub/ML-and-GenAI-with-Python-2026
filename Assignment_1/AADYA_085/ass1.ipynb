# %%
#Find simple interest.
p=float(input("Enter principle amount: "))
r=float(input("Enter rate of interest: "))
t=float(input("Enter Number of years: "))
print("simple interest: ",p*r*t/100)
# Out:
# Enter principle amount: 1000
# Enter rate of interest: 10
# Enter Number of years: 1
# simple interest:  100.0

# %%
#Convert temperature from Celsius to Fahrenheit.
C=float(input("Enter temperature in celsius: "))
f=(C*9/5)+32
print("temp in f is: ",f)
# Out:
# Enter temperature in celsius: 0
# temp in f is:  32.0

# %%
#Calculate average of 3 numbers
a=float(input("Enter first number: "))
b=float(input("Enter second number: "))
c=float(input("Enter fthird number: "))
avg=(a+b+c)/3
print("avg of 3 numbers is: ",avg)
# Out:
# Enter first number: 3
# Enter second number: 5
# Enter fthird number: 4
# avg of 3 numbers is:  4.0

# %%
#Find square and cube of a number.
a=float(input("Enter a number: "))
sq=a*a
cu=a*a*a
print("square of number is: ",sq)
print("cube of number is: ",cu)
# Out:
# Enter a number: 6
# square of number is:  36.0
# cube of number is:  216.0

# %%
#Swap two numbers without third variable.
a=float(input("Enter first number: "))
b=float(input("Enter second number: "))
a,b=b,a
print("a= ",a)
print("b= ",b)
# Out:
# Enter first number: 8
# Enter second number: 0
# a=  0.0
# b=  8.0

# %%
#Create a Student Report Program that take student details using input(), Store marks in variables, Calculate total and percentage , Use comments, Use proper indentation
name=input("Enter name: ")
enrollment=int(input("Enter enrollment number: "))
mathsmarks=int(input("Enter maths marks: "))
englishmarks=int(input("Enter english marks: "))
sciencemarks=int(input("Enter science marks: "))
total=mathsmarks+englishmarks+sciencemarks
perc=total/3
print("total marks : ",total)
print("percentage : ",perc)
# Out:
# Enter name: aadya
# Enter enrollment number085
# Enter maths marks: 100
# Enter english marks: 100
# Enter science marks: 100
# total marks :  300
# percentage :  100.0
